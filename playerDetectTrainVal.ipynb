# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48  Python-3.12.1 torch-2.3.1+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Setup complete  (12 CPUs, 13.9 GB RAM, 458.1/753.1 GB disk)

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8x.pt source='https://youtu.be/h-x26Mjd1Ec?si=8TdzkoEOcmgOpE1u' conf=0.85 save_crop=True device='cuda:0' show_labels=False show_conf=False show_boxes=False line_width=1

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/home/utku/BIL476/dataGreen/data.yaml" device='cuda:0' save=True epochs=10 val=True plots=True imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.74 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.70 🚀 Python-3.12.3 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5940MiB)
# ...

# %%
# !yolo task=detect mode=val model="C:/Users/Utku/Desktop/UTKU DERS/2023 03 YAZ/BİL476/PROJE/runs/detect/train/weights/best.pt" data="C:/Users/Utku/Desktop/UTKU DERS/2023 03 YAZ/BİL476/PROJE/data/data.yaml" save_json=True plots=True
# Out:
# Ultralytics YOLOv8.2.48 ğŸš€ Python-3.12.1 torch-2.3.1+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# ...
# val: New cache created: C:\Users\Utku\Desktop\UTKU DERS\2023 03 YAZ\BÄ°L476\PROJE\data\valid\labels.cache
#                    all        731        731      0.994      0.995      0.995      0.995
#                Arsenal        372        372      0.994      0.995      0.995      0.995
#                ManCity        359        359      0.994      0.994      0.995      0.995
# Speed: 0.3ms preprocess, 37.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Saving runs\detect\val3\predictions.json...
# Results saved to runs\detect\val3
# ğŸ’¡ Learn more at https://docs.ultralytics.com/modes/val
#   0%|          | 0.00/755k [00:00<?, ?B/s]
#  17%|#6        | 128k/755k [00:00<00:00, 1.26MB/s]
#  68%|######7   | 512k/755k [00:00<00:00, 2.70MB/s]
# 100%|##########| 755k/755k [00:00<00:00, 2.16MB/s]
# ...

# %%
# !yolo task=detect mode=predict model="C:/Users/Utku/Desktop/UTKU DERS/2023 03 YAZ/BİL476/PROJE/runs/detect/train/weights/best.pt" conf=0.75 source="C:/Users/Utku/Desktop/UTKU DERS/2023 03 YAZ/BİL476/PROJE/data/test" save=True
# Out:
# Ultralytics YOLOv8.2.48 ğŸš€ Python-3.12.1 torch-2.3.1+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1448 C:\Users\Utku\Desktop\UTKU DERS\2023 03 YAZ\BÄ°L476\PROJE\data\test\h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1000.jpg: 320x192 1 ManCity, 39.2ms
# image 2/1448 C:\Users\Utku\Desktop\UTKU DERS\2023 03 YAZ\BÄ°L476\PROJE\data\test\h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1016.jpg: 320x224 1 ManCity, 43.7ms
# image 3/1448 C:\Users\Utku\Desktop\UTKU DERS\2023 03 YAZ\BÄ°L476\PROJE\data\test\h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1028.jpg: 320x224 1 ManCity, 41.9ms
# image 4/1448 C:\Users\Utku\Desktop\UTKU DERS\2023 03 YAZ\BÄ°L476\PROJE\data\test\h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1029.jpg: 320x192 1 ManCity, 46.6ms
# image 5/1448 C:\Users\Utku\Desktop\UTKU DERS\2023 03 YAZ\BÄ°L476\PROJE\data\test\h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_10332.jpg: 320x192 1 ManCity, 46.6ms
# ...

# %%
# !yolo task=detect mode=predict model="/home/utku/BIL476/runs/detect/train/weights/best.pt" conf=0.25 source="/home/utku/BIL476/test2" save=True
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.12.3 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5940MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-26.png: 192x320 1 Arsenal, 59.7ms
# image 2/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-32.png: 192x320 1 Arsenal, 5.0ms
# image 3/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-35.png: 192x320 1 ManCity, 5.0ms
# image 4/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-37.png: 192x320 1 Arsenal, 1 ManCity, 5.2ms
# image 5/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-40.png: 192x320 1 Arsenal, 1 ManCity, 4.4ms
# image 6/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-42.png: 192x320 1 Arsenal, 1 ManCity, 4.4ms
# image 7/12 /home/utku/BIL476/test2/Screenshot from 2024-08-07 22-51-44.png: 192x320 1 Arsenal, 2 ManCitys, 4.4ms
# ...

# %%
# !yolo task=detect mode=predict model="/home/utku/BIL476/runs/detect/train3/weights/best.pt" conf=0.25 source="/home/utku/BIL476/dataGreen/test3" save=True
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.12.3 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5940MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1460 /home/utku/BIL476/dataGreen/test3/h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1000.jpg: 640x352 (no detections), 64.2ms
# image 2/1460 /home/utku/BIL476/dataGreen/test3/h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1016.jpg: 640x416 (no detections), 67.4ms
# image 3/1460 /home/utku/BIL476/dataGreen/test3/h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1028.jpg: 640x448 (no detections), 65.5ms
# image 4/1460 /home/utku/BIL476/dataGreen/test3/h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_1029.jpg: 640x352 (no detections), 4.8ms
# image 5/1460 /home/utku/BIL476/dataGreen/test3/h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_10332.jpg: 640x352 (no detections), 4.2ms
# image 6/1460 /home/utku/BIL476/dataGreen/test3/h-x26Mjd1Ec_si_8TdzkoEOcmgOpE1u_10342.jpg: 640x384 (no detections), 64.7ms
# ...
